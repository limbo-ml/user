# %%
import logging
logging.basicConfig(level=logging.WARN)

from IPython.display import display
import limbo.data

# %%
dataset = limbo.data.Dataset("../docs/data")
for sample in dataset:
    print(sample)
    if sample.synthetic and sample.synthetic.cryptomatte:
        print(sample.name)
        #sample.synthetic.cryptomatte.materialize_bounds()
        #sample.synthetic.cryptomatte.materialize_object_segmentation()
# Out:
# limbo.data.Sample(path='/Users/tshead/src/limbo-user/docs/data/image_0000000.json')
# image_0000000
# limbo.data.Sample(path='/Users/tshead/src/limbo-user/docs/data/image_0000025.json')
# image_0000025
# limbo.data.Sample(path='/Users/tshead/src/limbo-user/docs/data/image_0001785.json')
# image_0001785
# limbo.data.Sample(path='/Users/tshead/src/limbo-user/docs/data/image_0014.json')

# %%
display(sample.preview(show_bboxes=True, show_contours=True).makeImageSnapshot())
# Out:
# Image(1201, 804, ColorType.kRGBA_8888_ColorType, AlphaType.kPremul_AlphaType)

# %%
sample.metadata
# Out:
# {'annotations': [{'bbox': [292.8187255859375,
#     378.603759765625,
#     414.91790771484375,
#     294.28094482421875],
#    'bbox_mode': 'XYWH_ABS',
#    'category': '30B'},
#   {'category': 'real'},
#   {'category': '30'}],
#  'image': {'content-type': 'image/png',
#   'filename': 'image_0014.png',
#   'res': [1201, 804]},
#  'provenance': {'copyright': 'Katy Laffan / IAEA, 2019',
#   'license': 'Some rights reserved, Attribution 2.0 Generic (CC BY 2.0)',
#   'uri': 'https://www.flickr.com/photos/iaea_imagebank/49397817493/in/photolist-2ig7J9v-xgT4rJ-4FvLiE-7vnLKM'}}
