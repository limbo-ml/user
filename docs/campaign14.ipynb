# %% [raw]
# .. _campaign14:
#
# Campaign 14
# ===========

# %% [markdown]
# **Description**
#
# Each image contains individual type 30B containers surrounded by randomly-chosen distractor objects, viewed from above (it's the "Where's Waldo?" of uranium hexafluoride).  This data should be extremely challenging for models.

# %% [raw]
# .. image:: campaign14/3.png
#    :height: 200px
#    :align: left
#
# .. image:: campaign14/5.png
#    :height: 200px
#    :align: left
#
# .. image:: campaign14/33396.png
#    :height: 200px
#    :align: left

# %% [markdown]
# **Statistics**
#
# Total samples: 50000.
#
# - Samples with provenance: 0
# - Samples with images: 50000
# - Samples with synthetic data: 50000
# - Samples with cryptomatte data: 50000
# - Samples with bounding-boxes: 50000
# - Samples with empty bounding-boxes: 0
# - Samples with contours: 50000
# - Samples with tags: 50000
#
#
# Categories:
#
# - Category *30B* samples: 34829
# - Category *bag/cement* samples: 7459
# - Category *bag/salt* samples: 16380
# - Category *bag/sand* samples: 15415
# - Category *banding* samples: 18973
# - Category *barrel/55G* samples: 45509
# - Category *barrel/wine* samples: 15815
# - Category *barrel/wine/blocking* samples: 15684
# - Category *block/cinder* samples: 5563
# - Category *block/generic* samples: 10458
# - Category *blocking/concrete* samples: 8145
# - Category *blocking/wood* samples: 8601
# - Category *box/cardboard* samples: 11763
# - Category *brick* samples: 4515
# - Category *crate/mil/large* samples: 13614
# - Category *crate/mil/long* samples: 16688
# - Category *crate/mil/medium* samples: 16117
# - Category *crate/mil/small* samples: 16987
# - Category *drywall* samples: 14113
# - Category *keg/30L* samples: 12194
# - Category *keg/50L* samples: 11959
# - Category *lumber/pine* samples: 16790
# - Category *mdf* samples: 14368
# - Category *paintbrush* samples: 27023
# - Category *paintcan/1G* samples: 35091
# - Category *pallet* samples: 45126
# - Category *steel/roll* samples: 7772
# - Category *synthetic* samples: 50000
# - Category *tank/gas/10kg* samples: 22635
# - Category *tank/gas/160L* samples: 14672
# - Category *tank/gas/20kg* samples: 24869
# - Category *tank/gas/30kg* samples: 24059
# - Category *tank/gas/6kg* samples: 31514
# - Category *tank/gas/8kg* samples: 23390
# - Category *tank/oil/A* samples: 7685
# - Category *tank/oil/B* samples: 9720
# - Category *tank/oil/C* samples: 16005
# - Category *tank/oil/D* samples: 9238
# - Category *tank/oil/E* samples: 13309
# - Category *tank/oil/F* samples: 11584
# - Category *tank/oil/G* samples: 13166
# - Category *tank/oil/H* samples: 16686
# - Category *tank/propane/500G* samples: 16754
# - Category *tank/water/IBC/275G* samples: 15411
# - Category *tank/water/plastic/1500L* samples: 13355
# - Category *tank/water/plastic/16G* samples: 12220
#
#
# **Category Definitions**
#
# - bag/cement: bags of cement neatly stacked on a forklift pallet.
# - bag/salt: bags of salt neatly stacked on a forklift pallet.
# - bag/sand: bags of sand neatly stacked on a forklift pallet.
# - banding: banding used to keep pallet loads of blocks intact.
# - barrel/55G: 55 gallon barrels.
# - barrel/wine: traditional oak wine barrels.
# - barrel/wine/blocking: wood blocks used to stack and support groups of wine barrels.
# - block/cinder: cinderblock neatly stacked on a forklift pallet.
# - block/generic: large masonry blocks neatly stacked on a forklift pallet.
# - box/cardboard: cardboard boxes neatly stacked on a forklift pallet.
# - brick: standard bricks, neatly stacked on a forklift pallet and covered in translucent plastic.
# - crate/mil/large, crate/mil/long, crate/mil/medium, crate/mil/small: four different sizes of plastic military crate.
# - drywall: neat stack of sheets of drywall, covered in translucent plastic.
# - keg/30L, keg/50L: two sizes of beer keg.
# - lumber/pine: neat stack of pine lumber.
# - mdf: neat stack of sheets of MDF
# - paintbrush: standard bristle paintbrush.
# - paintcan/1G: one gallon paint can.
# - pallet: wood forklift pallet.
# - steel/roll: large roll of sheet metal.
# - synthetic: samples generated using our synthetic workflow.
# - tank/gas/6kg - tank/gas/160L: various sizes of gas cylinder.
# - tank/oil/A - tank/oil/H: various types of large industrial oil storage.
# - tank/propane/500G: commonly seen household propane storage tank.
# - tank/water/IBC/275G, tank/water/plastic/1500L, tank/water/plastic/16G: various sizes of water storage.
#
# **Questions**
#
# <dl>
#   <dt>Why are there only 34829 samples with the 30B category?</dt>
#   <dd>Due to differences in size among distractors (ranging from a paint can to a massive oil tank) and random camera placement, the type 30B containers may not always be visible in the final image.</dd>
# </dl>
