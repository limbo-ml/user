# %% [raw]
# .. _campaign11:
#
# Campaign 11
# ===========

# %% [markdown]
# **Description**
#
# Each image contains individual 30B containers surrounded by groups of randomly-chosen distractor objects.

# %% [raw]
# .. image:: campaign11/12118.png
#    :height: 200px
#    :align: left
#
# .. image:: campaign11/23535.png
#    :height: 200px
#    :align: left
#
# .. image:: campaign11/33426.png
#    :height: 200px
#    :align: left

# %% [markdown]
# Note that, due to differences in size among distractors (ranging from a paint can to a massive oil tank) and random camera placement, the 30B containers may not always be visible in the actual image.
#
# **Statistics**
#
# Total samples: 50000.
#
# - Samples with provenance: 0
# - Samples with images: 49998
# - Samples with synthetic data: 50000
# - Samples with cryptomatte data: 50000
# - Samples with bounding-boxes: 49998
# - Samples with empty bounding-boxes: 0
# - Samples with contours: 49998
# - Samples with tags: 50000
#
# Categories:
#
# - Category *30B* samples: 49588
# - Category *bag/cement* samples: 677
# - Category *bag/salt* samples: 757
# - Category *bag/sand* samples: 734
# - Category *banding* samples: 1889
# - Category *barrel/55G* samples: 11128
# - Category *barrel/wine* samples: 10032
# - Category *barrel/wine/blocking* samples: 9966
# - Category *block/cinder* samples: 609
# - Category *block/generic* samples: 664
# - Category *blocking/concrete* samples: 15338
# - Category *blocking/wood* samples: 15434
# - Category *box/cardboard* samples: 738
# - Category *brick* samples: 597
# - Category *crate/mil/large* samples: 2045
# - Category *crate/mil/long* samples: 2899
# - Category *crate/mil/medium* samples: 2328
# - Category *crate/mil/small* samples: 3060
# - Category *drywall* samples: 884
# - Category *keg/30L* samples: 6168
# - Category *keg/50L* samples: 6045
# - Category *lumber/pine* samples: 1202
# - Category *mdf* samples: 1167
# - Category *paintbrush* samples: 7120
# - Category *paintcan/1G* samples: 11953
# - Category *pallet* samples: 5327
# - Category *steel/roll* samples: 591
# - Category *synthetic* samples: 50000
# - Category *tank/gas/10kg* samples: 2406
# - Category *tank/gas/160L* samples: 1274
# - Category *tank/gas/20kg* samples: 2461
# - Category *tank/gas/30kg* samples: 1483
# - Category *tank/gas/6kg* samples: 3294
# - Category *tank/gas/8kg* samples: 1715
# - Category *tank/oil/A* samples: 1614
# - Category *tank/oil/B* samples: 1681
# - Category *tank/oil/C* samples: 1820
# - Category *tank/oil/D* samples: 1741
# - Category *tank/oil/F* samples: 1714
# - Category *tank/oil/G* samples: 1748
# - Category *tank/oil/H* samples: 1826
# - Category *tank/propane/500G* samples: 12699
# - Category *tank/water/IBC/275G* samples: 2964
# - Category *tank/water/plastic/1500L* samples: 2923
# - Category *tank/water/plastic/16G* samples: 3949
#
# **Category Definitions**
#
# - bag/cement: bags of cement neatly stacked on a forklift pallet.
# - bag/salt: bags of salt neatly stacked on a forklift pallet.
# - bag/sand: bags of sand neatly stacked on a forklift pallet.
# - banding: banding used to keep pallet loads of blocks intact.
# - barrel/55G: 55 gallon barrels.
# - barrel/wine: traditional oak wine barrels.
# - barrel/wine/blocking: wood blocks used to stack and support groups of wine barrels.
# - block/cinder: cinderblock neatly stacked on a forklift pallet.
# - block/generic: large masonry blocks neatly stacked on a forklift pallet.
# - box/cardboard: cardboard boxes neatly stacked on a forklift pallet.
# - brick: standard bricks, neatly stacked on a forklift pallet and covered in translucent plastic.
# - crate/mil/large, crate/mil/long, crate/mil/medium, crate/mil/small: four different sizes of plastic military crate.
# - drywall: neat stack of sheets of drywall, covered in translucent plastic.
# - keg/30L, keg/50L: two sizes of beer keg.
# - lumber/pine: neat stack of pine lumber.
# - mdf: neat stack of sheets of MDF
# - paintbrush: standard bristle paintbrush.
# - paintcan/1G: one gallon paint can.
# - pallet: wood forklift pallet.
# - steel/roll: large roll of sheet metal.
# - synthetic: samples generated using our synthetic workflow.
# - tank/gas/6kg - tank/gas/160L: various sizes of gas cylinder.
# - tank/oil/A - tank/oil/H: various types of large industrial oil storage.
# - tank/propane/500G: commonly seen household propane storage tank.
# - tank/water/IBC/275G, tank/water/plastic/1500L, tank/water/plastic/16G: various sizes of water storage.
#
# **Questions**
#
# <dl>
#   <dt>Why are there only 49998 samples with bounding boxes?</dt>
#   <dd>In theory, every sample should contain at least one bounding box.  However, our randomly chosen camera angles occasionally put all of the class instances completely off screen.  This leads to a sample tagged *synthetic* that doesn't contain any bounding boxes.</dd>
# </dl>
