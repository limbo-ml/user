# %% [raw]
# .. _campaign9:
#
# Campaign 9
# ==========

# %% [markdown]
# **Description**
#
# One type-48 container plus one nearby distractor.

# %% [raw]
# .. image:: campaign9/4557.png
#    :height: 200px
#    :align: left
#
# .. image:: campaign9/5826.png
#    :height: 200px
#    :align: left
#
# .. image:: campaign9/6802.png
#    :height: 200px
#    :align: left

# %% [markdown]
# **Statistics**
#
# Total samples: 50000.
#
# - Samples with provenance: 0
# - Samples with images: 50000
# - Samples with synthetic data: 50000
# - Samples with cryptomatte data: 50000
# - Samples with bounding-boxes: 49991
# - Samples with contours: 49991
# - Samples with tags: 50000
#
# Categories:
#
# - Category *48G* samples: 16431
# - Category *48X* samples: 16598
# - Category *48Y* samples: 16485
# - Category *bag/cement* samples: 375
# - Category *bag/salt* samples: 368
# - Category *bag/sand* samples: 292
# - Category *banding* samples: 990
# - Category *barrel/55G* samples: 3560
# - Category *barrel/55G/A* samples: 249
# - Category *barrel/55G/B* samples: 251
# - Category *barrel/55G/C* samples: 257
# - Category *barrel/55G/D* samples: 258
# - Category *barrel/55G/E* samples: 260
# - Category *barrel/55G/F* samples: 271
# - Category *block/cinder* samples: 373
# - Category *block/generic* samples: 328
# - Category *blocking/concrete* samples: 15563
# - Category *blocking/wood* samples: 15575
# - Category *box/cardboard* samples: 334
# - Category *brick* samples: 359
# - Category *crate/mil/large* samples: 961
# - Category *crate/mil/long* samples: 969
# - Category *crate/mil/medium* samples: 919
# - Category *crate/mil/small* samples: 837
# - Category *drywall* samples: 354
# - Category *keg/30L* samples: 1673
# - Category *keg/50L* samples: 1743
# - Category *lumber/pine* samples: 423
# - Category *mdf* samples: 388
# - Category *paintbrush* samples: 1778
# - Category *paintcan/1G* samples: 3262
# - Category *pallet* samples: 2727
# - Category *steel/roll* samples: 318
# - Category *synthetic* samples: 50000
# - Category *tank/gas/10kg* samples: 617
# - Category *tank/gas/160L* samples: 505
# - Category *tank/gas/20kg* samples: 689
# - Category *tank/gas/30kg* samples: 430
# - Category *tank/gas/6kg* samples: 774
# - Category *tank/gas/8kg* samples: 460
# - Category *tank/oil/A* samples: 625
# - Category *tank/oil/B* samples: 600
# - Category *tank/oil/C* samples: 587
# - Category *tank/oil/D* samples: 656
# - Category *tank/oil/E* samples: 626
# - Category *tank/oil/F* samples: 630
# - Category *tank/oil/G* samples: 599
# - Category *tank/oil/H* samples: 576
# - Category *tank/propane/500G* samples: 4245
# - Category *tank/water/IBC/275G* samples: 1385
# - Category *tank/water/plastic/1500L* samples: 1369
# - Category *tank/water/plastic/16G* samples: 1143
#
# Annotations:
#
# - Samples annotated *synthetic*: 9
# - Samples annotated *synthetic* + *tank/water/plastic/1500L*: 4
# - Samples annotated *synthetic* + *tank/water/IBC/275G*: 5
# - Samples annotated *synthetic* + *tank/propane/500G*: 15
# - Samples annotated *synthetic* + *tank/oil/H*: 10
# - Samples annotated *synthetic* + *tank/oil/G*: 1
# - Samples annotated *synthetic* + *tank/oil/F*: 64
# - Samples annotated *synthetic* + *tank/oil/E*: 106
# - Samples annotated *synthetic* + *tank/oil/D*: 9
# - Samples annotated *synthetic* + *tank/oil/C*: 78
# - Samples annotated *synthetic* + *tank/oil/B*: 71
# - Samples annotated *synthetic* + *tank/oil/A*: 90
# - Samples annotated *synthetic* + *tank/gas/10kg*: 1
# - Samples annotated *steel/roll* + *synthetic*: 1
# - Samples annotated *mdf* + *synthetic*: 3
# - Samples annotated *lumber/pine* + *synthetic*: 1
# - Samples annotated *crate/mil/large* + *synthetic*: 2
# - Samples annotated *brick* + *synthetic*: 1
# - Samples annotated *brick* + *pallet* + *synthetic*: 1
# - Samples annotated *blocking/wood* + *synthetic*: 1
# - Samples annotated *blocking/wood* + *synthetic* + *tank/oil/A*: 1
# - Samples annotated *blocking/concrete* + *synthetic*: 1
# - Samples annotated *blocking/concrete* + *synthetic* + *tank/oil/D*: 1
# - Samples annotated *block/cinder* + *synthetic*: 2
# - Samples annotated *barrel/55G* + *synthetic*: 1
# - Samples annotated *banding* + *block/generic* + *synthetic*: 1
# - Samples annotated *banding* + *block/generic* + *pallet* + *synthetic*: 2
# - Samples annotated *banding* + *block/cinder* + *pallet* + *synthetic*: 1
# - Samples annotated *bag/salt* + *pallet* + *synthetic*: 1
# - Samples annotated *bag/cement* + *synthetic*: 2
# - Samples annotated *48Y* + *synthetic*: 2084
# - Samples annotated *48Y* + *synthetic* + *tank/water/plastic/16G*: 139
# - Samples annotated *48Y* + *synthetic* + *tank/water/plastic/1500L*: 171
# - Samples annotated *48Y* + *synthetic* + *tank/water/IBC/275G*: 149
# - Samples annotated *48Y* + *synthetic* + *tank/propane/500G*: 537
# - Samples annotated *48Y* + *synthetic* + *tank/oil/H*: 60
# - Samples annotated *48Y* + *synthetic* + *tank/oil/G*: 71
# - Samples annotated *48Y* + *synthetic* + *tank/oil/F*: 60
# - Samples annotated *48Y* + *synthetic* + *tank/oil/E*: 83
# - Samples annotated *48Y* + *synthetic* + *tank/oil/D*: 80
# - Samples annotated *48Y* + *synthetic* + *tank/oil/C*: 90
# - Samples annotated *48Y* + *synthetic* + *tank/oil/B*: 51
# - Samples annotated *48Y* + *synthetic* + *tank/oil/A*: 82
# - Samples annotated *48Y* + *synthetic* + *tank/gas/8kg*: 51
# - Samples annotated *48Y* + *synthetic* + *tank/gas/6kg*: 82
# - Samples annotated *48Y* + *synthetic* + *tank/gas/30kg*: 49
# - Samples annotated *48Y* + *synthetic* + *tank/gas/20kg*: 75
# - Samples annotated *48Y* + *synthetic* + *tank/gas/160L*: 73
# - Samples annotated *48Y* + *synthetic* + *tank/gas/10kg*: 61
# - Samples annotated *48Y* + *steel/roll* + *synthetic*: 4
# - Samples annotated *48Y* + *pallet* + *synthetic*: 6
# - Samples annotated *48Y* + *pallet* + *steel/roll* + *synthetic*: 30
# - Samples annotated *48Y* + *paintcan/1G* + *synthetic*: 151
# - Samples annotated *48Y* + *paintbrush* + *paintcan/1G* + *synthetic*: 200
# - Samples annotated *48Y* + *mdf* + *synthetic*: 45
# - Samples annotated *48Y* + *lumber/pine* + *synthetic*: 69
# - Samples annotated *48Y* + *keg/50L* + *synthetic*: 212
# - Samples annotated *48Y* + *keg/30L* + *synthetic*: 168
# - Samples annotated *48Y* + *drywall* + *synthetic*: 42
# - Samples annotated *48Y* + *crate/mil/small* + *synthetic*: 85
# - Samples annotated *48Y* + *crate/mil/medium* + *synthetic*: 111
# - Samples annotated *48Y* + *crate/mil/long* + *synthetic*: 97
# - Samples annotated *48Y* + *crate/mil/large* + *synthetic*: 125
# - Samples annotated *48Y* + *brick* + *synthetic*: 4
# - Samples annotated *48Y* + *brick* + *pallet* + *synthetic*: 17
# - Samples annotated *48Y* + *box/cardboard* + *synthetic*: 5
# - Samples annotated *48Y* + *box/cardboard* + *pallet* + *synthetic*: 33
# - Samples annotated *48Y* + *blocking/wood* + *synthetic*: 1568
# - Samples annotated *48Y* + *blocking/wood* + *synthetic* + *tank/water/plastic/16G*: 126
# - Samples annotated *48Y* + *blocking/wood* + *synthetic* + *tank/water/plastic/1500L*: 137
# - Samples annotated *48Y* + *blocking/wood* + *synthetic* + *tank/water/IBC/275G*: 144
# - Samples annotated *48Y* + *blocking/wood* + *synthetic* + *tank/propane/500G*: 409
# - Samples annotated *48Y* + *blocking/wood* + *synthetic* + *tank/oil/H*: 51
# - Samples annotated *48Y* + *blocking/wood* + *synthetic* + *tank/oil/G*: 62
# - Samples annotated *48Y* + *blocking/wood* + *synthetic* + *tank/oil/F*: 33
# - Samples annotated *48Y* + *blocking/wood* + *synthetic* + *tank/oil/E*: 64
# - Samples annotated *48Y* + *blocking/wood* + *synthetic* + *tank/oil/D*: 91
# - Samples annotated *48Y* + *blocking/wood* + *synthetic* + *tank/oil/C*: 53
# - Samples annotated *48Y* + *blocking/wood* + *synthetic* + *tank/oil/B*: 58
# - Samples annotated *48Y* + *blocking/wood* + *synthetic* + *tank/oil/A*: 51
# - Samples annotated *48Y* + *blocking/wood* + *synthetic* + *tank/gas/8kg*: 52
# - Samples annotated *48Y* + *blocking/wood* + *synthetic* + *tank/gas/6kg*: 79
# - Samples annotated *48Y* + *blocking/wood* + *synthetic* + *tank/gas/30kg*: 44
# - Samples annotated *48Y* + *blocking/wood* + *synthetic* + *tank/gas/20kg*: 58
# - Samples annotated *48Y* + *blocking/wood* + *synthetic* + *tank/gas/160L*: 47
# - Samples annotated *48Y* + *blocking/wood* + *synthetic* + *tank/gas/10kg*: 70
# - Samples annotated *48Y* + *blocking/wood* + *steel/roll* + *synthetic*: 4
# - Samples annotated *48Y* + *blocking/wood* + *pallet* + *synthetic*: 14
# - Samples annotated *48Y* + *blocking/wood* + *pallet* + *steel/roll* + *synthetic*: 29
# - Samples annotated *48Y* + *blocking/wood* + *paintcan/1G* + *synthetic*: 183
# - Samples annotated *48Y* + *blocking/wood* + *paintbrush* + *synthetic*: 1
# - Samples annotated *48Y* + *blocking/wood* + *paintbrush* + *paintcan/1G* + *synthetic*: 188
# - Samples annotated *48Y* + *blocking/wood* + *mdf* + *synthetic*: 33
# - Samples annotated *48Y* + *blocking/wood* + *lumber/pine* + *synthetic*: 40
# - Samples annotated *48Y* + *blocking/wood* + *keg/50L* + *synthetic*: 182
# - Samples annotated *48Y* + *blocking/wood* + *keg/30L* + *synthetic*: 195
# - Samples annotated *48Y* + *blocking/wood* + *drywall* + *synthetic*: 34
# - Samples annotated *48Y* + *blocking/wood* + *crate/mil/small* + *synthetic*: 91
# - Samples annotated *48Y* + *blocking/wood* + *crate/mil/medium* + *synthetic*: 89
# - Samples annotated *48Y* + *blocking/wood* + *crate/mil/long* + *synthetic*: 111
# - Samples annotated *48Y* + *blocking/wood* + *crate/mil/large* + *synthetic*: 77
# - Samples annotated *48Y* + *blocking/wood* + *brick* + *synthetic*: 6
# - Samples annotated *48Y* + *blocking/wood* + *brick* + *pallet* + *synthetic*: 37
# - Samples annotated *48Y* + *blocking/wood* + *box/cardboard* + *synthetic*: 3
# - Samples annotated *48Y* + *blocking/wood* + *box/cardboard* + *pallet* + *synthetic*: 33
# - Samples annotated *48Y* + *blocking/concrete* + *synthetic*: 1683
# - Samples annotated *48Y* + *blocking/concrete* + *synthetic* + *tank/water/plastic/16G*: 111
# - Samples annotated *48Y* + *blocking/concrete* + *synthetic* + *tank/water/plastic/1500L*: 126
# - Samples annotated *48Y* + *blocking/concrete* + *synthetic* + *tank/water/IBC/275G*: 130
# - Samples annotated *48Y* + *blocking/concrete* + *synthetic* + *tank/propane/500G*: 465
# - Samples annotated *48Y* + *blocking/concrete* + *synthetic* + *tank/oil/H*: 51
# - Samples annotated *48Y* + *blocking/concrete* + *synthetic* + *tank/oil/G*: 56
# - Samples annotated *48Y* + *blocking/concrete* + *synthetic* + *tank/oil/F*: 58
# - Samples annotated *48Y* + *blocking/concrete* + *synthetic* + *tank/oil/E*: 52
# - Samples annotated *48Y* + *blocking/concrete* + *synthetic* + *tank/oil/D*: 71
# - Samples annotated *48Y* + *blocking/concrete* + *synthetic* + *tank/oil/C*: 41
# - Samples annotated *48Y* + *blocking/concrete* + *synthetic* + *tank/oil/B*: 62
# - Samples annotated *48Y* + *blocking/concrete* + *synthetic* + *tank/oil/A*: 52
# - Samples annotated *48Y* + *blocking/concrete* + *synthetic* + *tank/gas/8kg*: 45
# - Samples annotated *48Y* + *blocking/concrete* + *synthetic* + *tank/gas/6kg*: 87
# - Samples annotated *48Y* + *blocking/concrete* + *synthetic* + *tank/gas/30kg*: 62
# - Samples annotated *48Y* + *blocking/concrete* + *synthetic* + *tank/gas/20kg*: 65
# - Samples annotated *48Y* + *blocking/concrete* + *synthetic* + *tank/gas/160L*: 58
# - Samples annotated *48Y* + *blocking/concrete* + *synthetic* + *tank/gas/10kg*: 72
# - Samples annotated *48Y* + *blocking/concrete* + *steel/roll* + *synthetic*: 7
# - Samples annotated *48Y* + *blocking/concrete* + *pallet* + *synthetic*: 7
# - Samples annotated *48Y* + *blocking/concrete* + *pallet* + *steel/roll* + *synthetic*: 35
# - Samples annotated *48Y* + *blocking/concrete* + *paintcan/1G* + *synthetic*: 151
# - Samples annotated *48Y* + *blocking/concrete* + *paintbrush* + *paintcan/1G* + *synthetic*: 177
# - Samples annotated *48Y* + *blocking/concrete* + *mdf* + *synthetic*: 39
# - Samples annotated *48Y* + *blocking/concrete* + *lumber/pine* + *synthetic*: 31
# - Samples annotated *48Y* + *blocking/concrete* + *keg/50L* + *synthetic*: 188
# - Samples annotated *48Y* + *blocking/concrete* + *keg/30L* + *synthetic*: 164
# - Samples annotated *48Y* + *blocking/concrete* + *drywall* + *synthetic*: 29
# - Samples annotated *48Y* + *blocking/concrete* + *crate/mil/small* + *synthetic*: 90
# - Samples annotated *48Y* + *blocking/concrete* + *crate/mil/medium* + *synthetic*: 81
# - Samples annotated *48Y* + *blocking/concrete* + *crate/mil/long* + *synthetic*: 107
# - Samples annotated *48Y* + *blocking/concrete* + *crate/mil/large* + *synthetic*: 103
# - Samples annotated *48Y* + *blocking/concrete* + *brick* + *synthetic*: 6
# - Samples annotated *48Y* + *blocking/concrete* + *brick* + *pallet* + *synthetic*: 29
# - Samples annotated *48Y* + *blocking/concrete* + *box/cardboard* + *synthetic*: 7
# - Samples annotated *48Y* + *blocking/concrete* + *box/cardboard* + *pallet* + *synthetic*: 28
# - Samples annotated *48Y* + *block/generic* + *synthetic*: 1
# - Samples annotated *48Y* + *block/cinder* + *blocking/concrete* + *synthetic*: 1
# - Samples annotated *48Y* + *barrel/55G* + *synthetic*: 449
# - Samples annotated *48Y* + *barrel/55G* + *blocking/wood* + *synthetic*: 380
# - Samples annotated *48Y* + *barrel/55G* + *blocking/concrete* + *synthetic*: 378
# - Samples annotated *48Y* + *banding* + *synthetic*: 1
# - Samples annotated *48Y* + *banding* + *block/generic* + *synthetic*: 11
# - Samples annotated *48Y* + *banding* + *block/generic* + *pallet* + *synthetic*: 36
# - Samples annotated *48Y* + *banding* + *block/generic* + *blocking/wood* + *synthetic*: 1
# - Samples annotated *48Y* + *banding* + *block/generic* + *blocking/wood* + *pallet* + *synthetic*: 26
# - Samples annotated *48Y* + *banding* + *block/generic* + *blocking/concrete* + *synthetic*: 3
# - Samples annotated *48Y* + *banding* + *block/generic* + *blocking/concrete* + *pallet* + *synthetic*: 26
# - Samples annotated *48Y* + *banding* + *block/cinder* + *synthetic*: 11
# - Samples annotated *48Y* + *banding* + *block/cinder* + *pallet* + *synthetic*: 39
# - Samples annotated *48Y* + *banding* + *block/cinder* + *blocking/wood* + *synthetic*: 1
# - Samples annotated *48Y* + *banding* + *block/cinder* + *blocking/wood* + *pallet* + *synthetic*: 30
# - Samples annotated *48Y* + *banding* + *block/cinder* + *blocking/concrete* + *synthetic*: 4
# - Samples annotated *48Y* + *banding* + *block/cinder* + *blocking/concrete* + *pallet* + *synthetic*: 35
# - Samples annotated *48Y* + *banding* + *barrel/55G/F* + *pallet* + *synthetic*: 1
# - Samples annotated *48Y* + *banding* + *barrel/55G/E* + *barrel/55G/F* + *pallet* + *synthetic*: 1
# - Samples annotated *48Y* + *banding* + *barrel/55G/D* + *blocking/wood* + *pallet* + *synthetic*: 1
# - Samples annotated *48Y* + *banding* + *barrel/55G/D* + *barrel/55G/E* + *barrel/55G/F* + *blocking/wood* + *pallet* + *synthetic*: 3
# - Samples annotated *48Y* + *banding* + *barrel/55G/C* + *blocking/concrete* + *pallet* + *synthetic*: 1
# - Samples annotated *48Y* + *banding* + *barrel/55G/C* + *barrel/55G/F* + *pallet* + *synthetic*: 1
# - Samples annotated *48Y* + *banding* + *barrel/55G/C* + *barrel/55G/F* + *blocking/wood* + *pallet* + *synthetic*: 2
# - Samples annotated *48Y* + *banding* + *barrel/55G/C* + *barrel/55G/F* + *blocking/concrete* + *pallet* + *synthetic*: 1
# - Samples annotated *48Y* + *banding* + *barrel/55G/C* + *barrel/55G/E* + *barrel/55G/F* + *pallet* + *synthetic*: 2
# - Samples annotated *48Y* + *banding* + *barrel/55G/C* + *barrel/55G/D* + *barrel/55G/E* + *barrel/55G/F* + *blocking/wood* + *pallet* + *synthetic*: 1
# - Samples annotated *48Y* + *banding* + *barrel/55G/B* + *barrel/55G/C* + *blocking/concrete* + *synthetic*: 1
# - Samples annotated *48Y* + *banding* + *barrel/55G/B* + *barrel/55G/C* + *barrel/55G/E* + *barrel/55G/F* + *synthetic*: 1
# - Samples annotated *48Y* + *banding* + *barrel/55G/B* + *barrel/55G/C* + *barrel/55G/D* + *barrel/55G/E* + *barrel/55G/F* + *pallet* + *synthetic*: 2
# - Samples annotated *48Y* + *banding* + *barrel/55G/A* + *barrel/55G/D* + *pallet* + *synthetic*: 1
# - Samples annotated *48Y* + *banding* + *barrel/55G/A* + *barrel/55G/D* + *blocking/concrete* + *synthetic*: 1
# - Samples annotated *48Y* + *banding* + *barrel/55G/A* + *barrel/55G/D* + *barrel/55G/E* + *blocking/concrete* + *pallet* + *synthetic*: 1
# - Samples annotated *48Y* + *banding* + *barrel/55G/A* + *barrel/55G/D* + *barrel/55G/E* + *barrel/55G/F* + *blocking/wood* + *pallet* + *synthetic*: 3
# - Samples annotated *48Y* + *banding* + *barrel/55G/A* + *barrel/55G/D* + *barrel/55G/E* + *barrel/55G/F* + *blocking/concrete* + *pallet* + *synthetic*: 1
# - Samples annotated *48Y* + *banding* + *barrel/55G/A* + *barrel/55G/B* + *barrel/55G/D* + *pallet* + *synthetic*: 1
# - Samples annotated *48Y* + *banding* + *barrel/55G/A* + *barrel/55G/B* + *barrel/55G/D* + *blocking/concrete* + *pallet* + *synthetic*: 1
# - Samples annotated *48Y* + *banding* + *barrel/55G/A* + *barrel/55G/B* + *barrel/55G/D* + *barrel/55G/E* + *synthetic*: 1
# - Samples annotated *48Y* + *banding* + *barrel/55G/A* + *barrel/55G/B* + *barrel/55G/D* + *barrel/55G/E* + *barrel/55G/F* + *blocking/wood* + *pallet* + *synthetic*: 1
# - Samples annotated *48Y* + *banding* + *barrel/55G/A* + *barrel/55G/B* + *barrel/55G/D* + *barrel/55G/E* + *barrel/55G/F* + *blocking/concrete* + *pallet* + *synthetic*: 2
# - Samples annotated *48Y* + *banding* + *barrel/55G/A* + *barrel/55G/B* + *barrel/55G/C* + *barrel/55G/F* + *pallet* + *synthetic*: 1
# - Samples annotated *48Y* + *banding* + *barrel/55G/A* + *barrel/55G/B* + *barrel/55G/C* + *barrel/55G/F* + *blocking/wood* + *pallet* + *synthetic*: 2
# - Samples annotated *48Y* + *banding* + *barrel/55G/A* + *barrel/55G/B* + *barrel/55G/C* + *barrel/55G/E* + *barrel/55G/F* + *pallet* + *synthetic*: 1
# - Samples annotated *48Y* + *banding* + *barrel/55G/A* + *barrel/55G/B* + *barrel/55G/C* + *barrel/55G/E* + *barrel/55G/F* + *blocking/concrete* + *pallet* + *synthetic*: 2
# - Samples annotated *48Y* + *banding* + *barrel/55G/A* + *barrel/55G/B* + *barrel/55G/C* + *barrel/55G/D* + *blocking/wood* + *pallet* + *synthetic*: 1
# - Samples annotated *48Y* + *banding* + *barrel/55G/A* + *barrel/55G/B* + *barrel/55G/C* + *barrel/55G/D* + *barrel/55G/E* + *pallet* + *synthetic*: 1
# - Samples annotated *48Y* + *banding* + *barrel/55G/A* + *barrel/55G/B* + *barrel/55G/C* + *barrel/55G/D* + *barrel/55G/E* + *barrel/55G/F* + *pallet* + *synthetic*: 19
# - Samples annotated *48Y* + *banding* + *barrel/55G/A* + *barrel/55G/B* + *barrel/55G/C* + *barrel/55G/D* + *barrel/55G/E* + *barrel/55G/F* + *blocking/wood* + *pallet* + *synthetic*: 22
# - Samples annotated *48Y* + *banding* + *barrel/55G/A* + *barrel/55G/B* + *barrel/55G/C* + *barrel/55G/D* + *barrel/55G/E* + *barrel/55G/F* + *blocking/concrete* + *pallet* + *synthetic*: 18
# - Samples annotated *48Y* + *bag/sand* + *synthetic*: 2
# - Samples annotated *48Y* + *bag/sand* + *pallet* + *synthetic*: 26
# - Samples annotated *48Y* + *bag/sand* + *blocking/wood* + *pallet* + *synthetic*: 28
# - Samples annotated *48Y* + *bag/sand* + *blocking/concrete* + *synthetic*: 2
# - Samples annotated *48Y* + *bag/sand* + *blocking/concrete* + *pallet* + *synthetic*: 31
# - Samples annotated *48Y* + *bag/salt* + *synthetic*: 18
# - Samples annotated *48Y* + *bag/salt* + *pallet* + *synthetic*: 33
# - Samples annotated *48Y* + *bag/salt* + *blocking/wood* + *synthetic*: 5
# - Samples annotated *48Y* + *bag/salt* + *blocking/wood* + *pallet* + *synthetic*: 35
# - Samples annotated *48Y* + *bag/salt* + *blocking/concrete* + *synthetic*: 4
# - Samples annotated *48Y* + *bag/salt* + *blocking/concrete* + *pallet* + *synthetic*: 29
# - Samples annotated *48Y* + *bag/cement* + *synthetic*: 14
# - Samples annotated *48Y* + *bag/cement* + *pallet* + *synthetic*: 34
# - Samples annotated *48Y* + *bag/cement* + *blocking/wood* + *synthetic*: 2
# - Samples annotated *48Y* + *bag/cement* + *blocking/wood* + *pallet* + *synthetic*: 30
# - Samples annotated *48Y* + *bag/cement* + *blocking/concrete* + *synthetic*: 9
# - Samples annotated *48Y* + *bag/cement* + *blocking/concrete* + *pallet* + *synthetic*: 27
# - Samples annotated *48X* + *synthetic*: 1920
# - Samples annotated *48X* + *synthetic* + *tank/water/plastic/16G*: 132
# - Samples annotated *48X* + *synthetic* + *tank/water/plastic/1500L*: 166
# - Samples annotated *48X* + *synthetic* + *tank/water/IBC/275G*: 186
# - Samples annotated *48X* + *synthetic* + *tank/propane/500G*: 528
# - Samples annotated *48X* + *synthetic* + *tank/oil/H*: 85
# - Samples annotated *48X* + *synthetic* + *tank/oil/G*: 70
# - Samples annotated *48X* + *synthetic* + *tank/oil/F*: 94
# - Samples annotated *48X* + *synthetic* + *tank/oil/E*: 60
# - Samples annotated *48X* + *synthetic* + *tank/oil/D*: 72
# - Samples annotated *48X* + *synthetic* + *tank/oil/C*: 65
# - Samples annotated *48X* + *synthetic* + *tank/oil/B*: 57
# - Samples annotated *48X* + *synthetic* + *tank/oil/A*: 64
# - Samples annotated *48X* + *synthetic* + *tank/gas/8kg*: 55
# - Samples annotated *48X* + *synthetic* + *tank/gas/6kg*: 103
# - Samples annotated *48X* + *synthetic* + *tank/gas/30kg*: 48
# - Samples annotated *48X* + *synthetic* + *tank/gas/20kg*: 75
# - Samples annotated *48X* + *synthetic* + *tank/gas/160L*: 71
# - Samples annotated *48X* + *synthetic* + *tank/gas/10kg*: 76
# - Samples annotated *48X* + *steel/roll* + *synthetic*: 6
# - Samples annotated *48X* + *pallet* + *synthetic*: 10
# - Samples annotated *48X* + *pallet* + *steel/roll* + *synthetic*: 37
# - Samples annotated *48X* + *paintcan/1G* + *synthetic*: 172
# - Samples annotated *48X* + *paintbrush* + *synthetic*: 1
# - Samples annotated *48X* + *paintbrush* + *paintcan/1G* + *synthetic*: 212
# - Samples annotated *48X* + *mdf* + *synthetic*: 57
# - Samples annotated *48X* + *lumber/pine* + *synthetic*: 59
# - Samples annotated *48X* + *keg/50L* + *synthetic*: 205
# - Samples annotated *48X* + *keg/30L* + *synthetic*: 201
# - Samples annotated *48X* + *drywall* + *synthetic*: 45
# - Samples annotated *48X* + *crate/mil/small* + *synthetic*: 105
# - Samples annotated *48X* + *crate/mil/medium* + *synthetic*: 109
# - Samples annotated *48X* + *crate/mil/long* + *synthetic*: 92
# - Samples annotated *48X* + *crate/mil/large* + *synthetic*: 133
# - Samples annotated *48X* + *brick* + *synthetic*: 11
# - Samples annotated *48X* + *brick* + *pallet* + *synthetic*: 51
# - Samples annotated *48X* + *box/cardboard* + *synthetic*: 2
# - Samples annotated *48X* + *box/cardboard* + *pallet* + *synthetic*: 32
# - Samples annotated *48X* + *blocking/wood* + *synthetic*: 1508
# - Samples annotated *48X* + *blocking/wood* + *synthetic* + *tank/water/plastic/16G*: 134
# - Samples annotated *48X* + *blocking/wood* + *synthetic* + *tank/water/plastic/1500L*: 166
# - Samples annotated *48X* + *blocking/wood* + *synthetic* + *tank/water/IBC/275G*: 145
# - Samples annotated *48X* + *blocking/wood* + *synthetic* + *tank/propane/500G*: 420
# - Samples annotated *48X* + *blocking/wood* + *synthetic* + *tank/oil/H*: 57
# - Samples annotated *48X* + *blocking/wood* + *synthetic* + *tank/oil/G*: 70
# - Samples annotated *48X* + *blocking/wood* + *synthetic* + *tank/oil/F*: 70
# - Samples annotated *48X* + *blocking/wood* + *synthetic* + *tank/oil/E*: 57
# - Samples annotated *48X* + *blocking/wood* + *synthetic* + *tank/oil/D*: 68
# - Samples annotated *48X* + *blocking/wood* + *synthetic* + *tank/oil/C*: 49
# - Samples annotated *48X* + *blocking/wood* + *synthetic* + *tank/oil/B*: 45
# - Samples annotated *48X* + *blocking/wood* + *synthetic* + *tank/oil/A*: 60
# - Samples annotated *48X* + *blocking/wood* + *synthetic* + *tank/gas/8kg*: 65
# - Samples annotated *48X* + *blocking/wood* + *synthetic* + *tank/gas/6kg*: 79
# - Samples annotated *48X* + *blocking/wood* + *synthetic* + *tank/gas/30kg*: 48
# - Samples annotated *48X* + *blocking/wood* + *synthetic* + *tank/gas/20kg*: 74
# - Samples annotated *48X* + *blocking/wood* + *synthetic* + *tank/gas/160L*: 45
# - Samples annotated *48X* + *blocking/wood* + *synthetic* + *tank/gas/10kg*: 70
# - Samples annotated *48X* + *blocking/wood* + *steel/roll* + *synthetic*: 4
# - Samples annotated *48X* + *blocking/wood* + *pallet* + *synthetic*: 11
# - Samples annotated *48X* + *blocking/wood* + *pallet* + *steel/roll* + *synthetic*: 28
# - Samples annotated *48X* + *blocking/wood* + *paintcan/1G* + *synthetic*: 186
# - Samples annotated *48X* + *blocking/wood* + *paintbrush* + *paintcan/1G* + *synthetic*: 210
# - Samples annotated *48X* + *blocking/wood* + *mdf* + *synthetic*: 47
# - Samples annotated *48X* + *blocking/wood* + *lumber/pine* + *synthetic*: 37
# - Samples annotated *48X* + *blocking/wood* + *keg/50L* + *synthetic*: 198
# - Samples annotated *48X* + *blocking/wood* + *keg/30L* + *synthetic*: 182
# - Samples annotated *48X* + *blocking/wood* + *drywall* + *synthetic*: 35
# - Samples annotated *48X* + *blocking/wood* + *crate/mil/small* + *synthetic*: 112
# - Samples annotated *48X* + *blocking/wood* + *crate/mil/medium* + *synthetic*: 104
# - Samples annotated *48X* + *blocking/wood* + *crate/mil/long* + *synthetic*: 118
# - Samples annotated *48X* + *blocking/wood* + *crate/mil/large* + *synthetic*: 107
# - Samples annotated *48X* + *blocking/wood* + *brick* + *synthetic*: 6
# - Samples annotated *48X* + *blocking/wood* + *brick* + *pallet* + *synthetic*: 33
# - Samples annotated *48X* + *blocking/wood* + *box/cardboard* + *synthetic*: 1
# - Samples annotated *48X* + *blocking/wood* + *box/cardboard* + *pallet* + *synthetic*: 35
# - Samples annotated *48X* + *blocking/concrete* + *synthetic*: 1442
# - Samples annotated *48X* + *blocking/concrete* + *synthetic* + *tank/water/plastic/16G*: 115
# - Samples annotated *48X* + *blocking/concrete* + *synthetic* + *tank/water/plastic/1500L*: 140
# - Samples annotated *48X* + *blocking/concrete* + *synthetic* + *tank/water/IBC/275G*: 160
# - Samples annotated *48X* + *blocking/concrete* + *synthetic* + *tank/propane/500G*: 466
# - Samples annotated *48X* + *blocking/concrete* + *synthetic* + *tank/oil/H*: 52
# - Samples annotated *48X* + *blocking/concrete* + *synthetic* + *tank/oil/G*: 79
# - Samples annotated *48X* + *blocking/concrete* + *synthetic* + *tank/oil/F*: 53
# - Samples annotated *48X* + *blocking/concrete* + *synthetic* + *tank/oil/E*: 45
# - Samples annotated *48X* + *blocking/concrete* + *synthetic* + *tank/oil/D*: 65
# - Samples annotated *48X* + *blocking/concrete* + *synthetic* + *tank/oil/C*: 49
# - Samples annotated *48X* + *blocking/concrete* + *synthetic* + *tank/oil/B*: 61
# - Samples annotated *48X* + *blocking/concrete* + *synthetic* + *tank/oil/A*: 39
# - Samples annotated *48X* + *blocking/concrete* + *synthetic* + *tank/gas/8kg*: 44
# - Samples annotated *48X* + *blocking/concrete* + *synthetic* + *tank/gas/6kg*: 100
# - Samples annotated *48X* + *blocking/concrete* + *synthetic* + *tank/gas/30kg*: 45
# - Samples annotated *48X* + *blocking/concrete* + *synthetic* + *tank/gas/20kg*: 90
# - Samples annotated *48X* + *blocking/concrete* + *synthetic* + *tank/gas/160L*: 60
# - Samples annotated *48X* + *blocking/concrete* + *synthetic* + *tank/gas/10kg*: 72
# - Samples annotated *48X* + *blocking/concrete* + *steel/roll* + *synthetic*: 4
# - Samples annotated *48X* + *blocking/concrete* + *pallet* + *synthetic*: 3
# - Samples annotated *48X* + *blocking/concrete* + *pallet* + *steel/roll* + *synthetic*: 23
# - Samples annotated *48X* + *blocking/concrete* + *paintcan/1G* + *synthetic*: 161
# - Samples annotated *48X* + *blocking/concrete* + *paintbrush* + *paintcan/1G* + *synthetic*: 201
# - Samples annotated *48X* + *blocking/concrete* + *mdf* + *synthetic*: 39
# - Samples annotated *48X* + *blocking/concrete* + *lumber/pine* + *synthetic*: 50
# - Samples annotated *48X* + *blocking/concrete* + *keg/50L* + *synthetic*: 184
# - Samples annotated *48X* + *blocking/concrete* + *keg/30L* + *synthetic*: 192
# - Samples annotated *48X* + *blocking/concrete* + *drywall* + *synthetic*: 41
# - Samples annotated *48X* + *blocking/concrete* + *crate/mil/small* + *synthetic*: 96
# - Samples annotated *48X* + *blocking/concrete* + *crate/mil/medium* + *synthetic*: 103
# - Samples annotated *48X* + *blocking/concrete* + *crate/mil/long* + *synthetic*: 113
# - Samples annotated *48X* + *blocking/concrete* + *crate/mil/large* + *synthetic*: 99
# - Samples annotated *48X* + *blocking/concrete* + *brick* + *synthetic*: 4
# - Samples annotated *48X* + *blocking/concrete* + *brick* + *pallet* + *synthetic*: 37
# - Samples annotated *48X* + *blocking/concrete* + *box/cardboard* + *pallet* + *synthetic*: 39
# - Samples annotated *48X* + *block/generic* + *blocking/wood* + *synthetic*: 2
# - Samples annotated *48X* + *block/cinder* + *synthetic*: 1
# - Samples annotated *48X* + *block/cinder* + *pallet* + *synthetic*: 2
# - Samples annotated *48X* + *block/cinder* + *blocking/wood* + *pallet* + *synthetic*: 1
# - Samples annotated *48X* + *barrel/55G/F* + *blocking/concrete* + *pallet* + *synthetic*: 1
# - Samples annotated *48X* + *barrel/55G/D* + *blocking/wood* + *pallet* + *synthetic*: 1
# - Samples annotated *48X* + *barrel/55G/D* + *blocking/concrete* + *pallet* + *synthetic*: 1
# - Samples annotated *48X* + *barrel/55G/D* + *barrel/55G/E* + *barrel/55G/F* + *synthetic*: 1
# - Samples annotated *48X* + *barrel/55G* + *synthetic*: 406
# - Samples annotated *48X* + *barrel/55G* + *blocking/wood* + *synthetic*: 378
# - Samples annotated *48X* + *barrel/55G* + *blocking/concrete* + *synthetic*: 411
# - Samples annotated *48X* + *banding* + *block/generic* + *synthetic*: 5
# - Samples annotated *48X* + *banding* + *block/generic* + *pallet* + *synthetic*: 36
# - Samples annotated *48X* + *banding* + *block/generic* + *blocking/wood* + *synthetic*: 3
# - Samples annotated *48X* + *banding* + *block/generic* + *blocking/wood* + *pallet* + *synthetic*: 29
# - Samples annotated *48X* + *banding* + *block/generic* + *blocking/concrete* + *synthetic*: 1
# - Samples annotated *48X* + *banding* + *block/generic* + *blocking/concrete* + *pallet* + *synthetic*: 32
# - Samples annotated *48X* + *banding* + *block/cinder* + *synthetic*: 8
# - Samples annotated *48X* + *banding* + *block/cinder* + *pallet* + *synthetic*: 35
# - Samples annotated *48X* + *banding* + *block/cinder* + *blocking/wood* + *synthetic*: 5
# - Samples annotated *48X* + *banding* + *block/cinder* + *blocking/wood* + *pallet* + *synthetic*: 37
# - Samples annotated *48X* + *banding* + *block/cinder* + *blocking/concrete* + *synthetic*: 7
# - Samples annotated *48X* + *banding* + *block/cinder* + *blocking/concrete* + *pallet* + *synthetic*: 26
# - Samples annotated *48X* + *banding* + *barrel/55G/F* + *blocking/wood* + *pallet* + *synthetic*: 1
# - Samples annotated *48X* + *banding* + *barrel/55G/F* + *blocking/concrete* + *pallet* + *synthetic*: 1
# - Samples annotated *48X* + *banding* + *barrel/55G/E* + *barrel/55G/F* + *blocking/wood* + *pallet* + *synthetic*: 2
# - Samples annotated *48X* + *banding* + *barrel/55G/D* + *barrel/55G/E* + *pallet* + *synthetic*: 1
# - Samples annotated *48X* + *banding* + *barrel/55G/C* + *blocking/wood* + *pallet* + *synthetic*: 1
# - Samples annotated *48X* + *banding* + *barrel/55G/C* + *barrel/55G/F* + *blocking/concrete* + *pallet* + *synthetic*: 1
# - Samples annotated *48X* + *banding* + *barrel/55G/C* + *barrel/55G/E* + *barrel/55G/F* + *blocking/wood* + *pallet* + *synthetic*: 1
# - Samples annotated *48X* + *banding* + *barrel/55G/C* + *barrel/55G/D* + *barrel/55G/E* + *barrel/55G/F* + *pallet* + *synthetic*: 1
# - Samples annotated *48X* + *banding* + *barrel/55G/C* + *barrel/55G/D* + *barrel/55G/E* + *barrel/55G/F* + *blocking/wood* + *pallet* + *synthetic*: 1
# - Samples annotated *48X* + *banding* + *barrel/55G/C* + *barrel/55G/D* + *barrel/55G/E* + *barrel/55G/F* + *blocking/concrete* + *pallet* + *synthetic*: 1
# - Samples annotated *48X* + *banding* + *barrel/55G/B* + *barrel/55G/C* + *barrel/55G/F* + *blocking/wood* + *pallet* + *synthetic*: 1
# - Samples annotated *48X* + *banding* + *barrel/55G/B* + *barrel/55G/C* + *barrel/55G/F* + *blocking/concrete* + *pallet* + *synthetic*: 1
# - Samples annotated *48X* + *banding* + *barrel/55G/B* + *barrel/55G/C* + *barrel/55G/E* + *blocking/concrete* + *pallet* + *synthetic*: 1
# - Samples annotated *48X* + *banding* + *barrel/55G/B* + *barrel/55G/C* + *barrel/55G/E* + *barrel/55G/F* + *pallet* + *synthetic*: 1
# - Samples annotated *48X* + *banding* + *barrel/55G/B* + *barrel/55G/C* + *barrel/55G/E* + *barrel/55G/F* + *blocking/concrete* + *pallet* + *synthetic*: 2
# - Samples annotated *48X* + *banding* + *barrel/55G/B* + *barrel/55G/C* + *barrel/55G/D* + *barrel/55G/E* + *barrel/55G/F* + *blocking/wood* + *pallet* + *synthetic*: 1
# - Samples annotated *48X* + *banding* + *barrel/55G/B* + *barrel/55G/C* + *barrel/55G/D* + *barrel/55G/E* + *barrel/55G/F* + *blocking/concrete* + *pallet* + *synthetic*: 2
# - Samples annotated *48X* + *banding* + *barrel/55G/A* + *barrel/55G/D* + *pallet* + *synthetic*: 4
# - Samples annotated *48X* + *banding* + *barrel/55G/A* + *barrel/55G/D* + *blocking/wood* + *pallet* + *synthetic*: 1
# - Samples annotated *48X* + *banding* + *barrel/55G/A* + *barrel/55G/D* + *barrel/55G/E* + *pallet* + *synthetic*: 1
# - Samples annotated *48X* + *banding* + *barrel/55G/A* + *barrel/55G/D* + *barrel/55G/E* + *blocking/wood* + *pallet* + *synthetic*: 1
# - Samples annotated *48X* + *banding* + *barrel/55G/A* + *barrel/55G/D* + *barrel/55G/E* + *blocking/concrete* + *pallet* + *synthetic*: 1
# - Samples annotated *48X* + *banding* + *barrel/55G/A* + *barrel/55G/D* + *barrel/55G/E* + *barrel/55G/F* + *blocking/concrete* + *pallet* + *synthetic*: 2
# - Samples annotated *48X* + *banding* + *barrel/55G/A* + *barrel/55G/B* + *barrel/55G/D* + *pallet* + *synthetic*: 1
# - Samples annotated *48X* + *banding* + *barrel/55G/A* + *barrel/55G/B* + *barrel/55G/D* + *barrel/55G/E* + *blocking/concrete* + *pallet* + *synthetic*: 1
# - Samples annotated *48X* + *banding* + *barrel/55G/A* + *barrel/55G/B* + *barrel/55G/D* + *barrel/55G/E* + *barrel/55G/F* + *pallet* + *synthetic*: 3
# - Samples annotated *48X* + *banding* + *barrel/55G/A* + *barrel/55G/B* + *barrel/55G/D* + *barrel/55G/E* + *barrel/55G/F* + *blocking/wood* + *pallet* + *synthetic*: 1
# - Samples annotated *48X* + *banding* + *barrel/55G/A* + *barrel/55G/B* + *barrel/55G/C* + *synthetic*: 1
# - Samples annotated *48X* + *banding* + *barrel/55G/A* + *barrel/55G/B* + *barrel/55G/C* + *pallet* + *synthetic*: 1
# - Samples annotated *48X* + *banding* + *barrel/55G/A* + *barrel/55G/B* + *barrel/55G/C* + *barrel/55G/F* + *pallet* + *synthetic*: 1
# - Samples annotated *48X* + *banding* + *barrel/55G/A* + *barrel/55G/B* + *barrel/55G/C* + *barrel/55G/D* + *blocking/concrete* + *pallet* + *synthetic*: 3
# - Samples annotated *48X* + *banding* + *barrel/55G/A* + *barrel/55G/B* + *barrel/55G/C* + *barrel/55G/D* + *barrel/55G/E* + *blocking/concrete* + *pallet* + *synthetic*: 1
# - Samples annotated *48X* + *banding* + *barrel/55G/A* + *barrel/55G/B* + *barrel/55G/C* + *barrel/55G/D* + *barrel/55G/E* + *barrel/55G/F* + *synthetic*: 1
# - Samples annotated *48X* + *banding* + *barrel/55G/A* + *barrel/55G/B* + *barrel/55G/C* + *barrel/55G/D* + *barrel/55G/E* + *barrel/55G/F* + *pallet* + *synthetic*: 23
# - Samples annotated *48X* + *banding* + *barrel/55G/A* + *barrel/55G/B* + *barrel/55G/C* + *barrel/55G/D* + *barrel/55G/E* + *barrel/55G/F* + *blocking/wood* + *pallet* + *synthetic*: 21
# - Samples annotated *48X* + *banding* + *barrel/55G/A* + *barrel/55G/B* + *barrel/55G/C* + *barrel/55G/D* + *barrel/55G/E* + *barrel/55G/F* + *blocking/concrete* + *pallet* + *synthetic*: 24
# - Samples annotated *48X* + *bag/sand* + *synthetic*: 5
# - Samples annotated *48X* + *bag/sand* + *pallet* + *synthetic*: 32
# - Samples annotated *48X* + *bag/sand* + *blocking/wood* + *synthetic*: 1
# - Samples annotated *48X* + *bag/sand* + *blocking/wood* + *pallet* + *synthetic*: 25
# - Samples annotated *48X* + *bag/sand* + *blocking/concrete* + *synthetic*: 1
# - Samples annotated *48X* + *bag/sand* + *blocking/concrete* + *pallet* + *synthetic*: 32
# - Samples annotated *48X* + *bag/salt* + *synthetic*: 9
# - Samples annotated *48X* + *bag/salt* + *pallet* + *synthetic*: 31
# - Samples annotated *48X* + *bag/salt* + *blocking/wood* + *pallet* + *synthetic*: 35
# - Samples annotated *48X* + *bag/salt* + *blocking/concrete* + *synthetic*: 7
# - Samples annotated *48X* + *bag/salt* + *blocking/concrete* + *pallet* + *synthetic*: 32
# - Samples annotated *48X* + *bag/cement* + *synthetic*: 10
# - Samples annotated *48X* + *bag/cement* + *pallet* + *synthetic*: 37
# - Samples annotated *48X* + *bag/cement* + *blocking/wood* + *synthetic*: 7
# - Samples annotated *48X* + *bag/cement* + *blocking/wood* + *pallet* + *synthetic*: 43
# - Samples annotated *48X* + *bag/cement* + *blocking/concrete* + *synthetic*: 4
# - Samples annotated *48X* + *bag/cement* + *blocking/concrete* + *pallet* + *synthetic*: 29
# - Samples annotated *48G* + *synthetic*: 1982
# - Samples annotated *48G* + *synthetic* + *tank/water/plastic/16G*: 114
# - Samples annotated *48G* + *synthetic* + *tank/water/plastic/1500L*: 170
# - Samples annotated *48G* + *synthetic* + *tank/water/IBC/275G*: 161
# - Samples annotated *48G* + *synthetic* + *tank/propane/500G*: 563
# - Samples annotated *48G* + *synthetic* + *tank/oil/H*: 78
# - Samples annotated *48G* + *synthetic* + *tank/oil/G*: 74
# - Samples annotated *48G* + *synthetic* + *tank/oil/F*: 80
# - Samples annotated *48G* + *synthetic* + *tank/oil/E*: 64
# - Samples annotated *48G* + *synthetic* + *tank/oil/D*: 65
# - Samples annotated *48G* + *synthetic* + *tank/oil/C*: 57
# - Samples annotated *48G* + *synthetic* + *tank/oil/B*: 87
# - Samples annotated *48G* + *synthetic* + *tank/oil/A*: 69
# - Samples annotated *48G* + *synthetic* + *tank/gas/8kg*: 54
# - Samples annotated *48G* + *synthetic* + *tank/gas/6kg*: 89
# - Samples annotated *48G* + *synthetic* + *tank/gas/30kg*: 40
# - Samples annotated *48G* + *synthetic* + *tank/gas/20kg*: 102
# - Samples annotated *48G* + *synthetic* + *tank/gas/160L*: 58
# - Samples annotated *48G* + *synthetic* + *tank/gas/10kg*: 70
# - Samples annotated *48G* + *steel/roll* + *synthetic*: 8
# - Samples annotated *48G* + *pallet* + *synthetic*: 5
# - Samples annotated *48G* + *pallet* + *steel/roll* + *synthetic*: 34
# - Samples annotated *48G* + *paintcan/1G* + *synthetic*: 146
# - Samples annotated *48G* + *paintbrush* + *paintcan/1G* + *synthetic*: 192
# - Samples annotated *48G* + *mdf* + *synthetic*: 52
# - Samples annotated *48G* + *lumber/pine* + *synthetic*: 65
# - Samples annotated *48G* + *keg/50L* + *synthetic*: 194
# - Samples annotated *48G* + *keg/30L* + *synthetic*: 193
# - Samples annotated *48G* + *drywall* + *synthetic*: 60
# - Samples annotated *48G* + *crate/mil/small* + *synthetic*: 78
# - Samples annotated *48G* + *crate/mil/medium* + *synthetic*: 122
# - Samples annotated *48G* + *crate/mil/long* + *synthetic*: 112
# - Samples annotated *48G* + *crate/mil/large* + *synthetic*: 119
# - Samples annotated *48G* + *brick* + *synthetic*: 10
# - Samples annotated *48G* + *brick* + *pallet* + *synthetic*: 34
# - Samples annotated *48G* + *box/cardboard* + *synthetic*: 6
# - Samples annotated *48G* + *box/cardboard* + *pallet* + *synthetic*: 46
# - Samples annotated *48G* + *blocking/wood* + *synthetic*: 1508
# - Samples annotated *48G* + *blocking/wood* + *synthetic* + *tank/water/plastic/16G*: 147
# - Samples annotated *48G* + *blocking/wood* + *synthetic* + *tank/water/plastic/1500L*: 148
# - Samples annotated *48G* + *blocking/wood* + *synthetic* + *tank/water/IBC/275G*: 159
# - Samples annotated *48G* + *blocking/wood* + *synthetic* + *tank/propane/500G*: 430
# - Samples annotated *48G* + *blocking/wood* + *synthetic* + *tank/oil/H*: 64
# - Samples annotated *48G* + *blocking/wood* + *synthetic* + *tank/oil/G*: 58
# - Samples annotated *48G* + *blocking/wood* + *synthetic* + *tank/oil/F*: 59
# - Samples annotated *48G* + *blocking/wood* + *synthetic* + *tank/oil/E*: 42
# - Samples annotated *48G* + *blocking/wood* + *synthetic* + *tank/oil/D*: 66
# - Samples annotated *48G* + *blocking/wood* + *synthetic* + *tank/oil/C*: 60
# - Samples annotated *48G* + *blocking/wood* + *synthetic* + *tank/oil/B*: 54
# - Samples annotated *48G* + *blocking/wood* + *synthetic* + *tank/oil/A*: 63
# - Samples annotated *48G* + *blocking/wood* + *synthetic* + *tank/gas/8kg*: 44
# - Samples annotated *48G* + *blocking/wood* + *synthetic* + *tank/gas/6kg*: 82
# - Samples annotated *48G* + *blocking/wood* + *synthetic* + *tank/gas/30kg*: 57
# - Samples annotated *48G* + *blocking/wood* + *synthetic* + *tank/gas/20kg*: 70
# - Samples annotated *48G* + *blocking/wood* + *synthetic* + *tank/gas/160L*: 47
# - Samples annotated *48G* + *blocking/wood* + *synthetic* + *tank/gas/10kg*: 67
# - Samples annotated *48G* + *blocking/wood* + *steel/roll* + *synthetic*: 2
# - Samples annotated *48G* + *blocking/wood* + *pallet* + *synthetic*: 8
# - Samples annotated *48G* + *blocking/wood* + *pallet* + *steel/roll* + *synthetic*: 31
# - Samples annotated *48G* + *blocking/wood* + *paintcan/1G* + *synthetic*: 181
# - Samples annotated *48G* + *blocking/wood* + *paintbrush* + *synthetic*: 1
# - Samples annotated *48G* + *blocking/wood* + *paintbrush* + *paintcan/1G* + *synthetic*: 206
# - Samples annotated *48G* + *blocking/wood* + *mdf* + *synthetic*: 41
# - Samples annotated *48G* + *blocking/wood* + *lumber/pine* + *synthetic*: 38
# - Samples annotated *48G* + *blocking/wood* + *keg/50L* + *synthetic*: 184
# - Samples annotated *48G* + *blocking/wood* + *keg/30L* + *synthetic*: 167
# - Samples annotated *48G* + *blocking/wood* + *drywall* + *synthetic*: 36
# - Samples annotated *48G* + *blocking/wood* + *crate/mil/small* + *synthetic*: 89
# - Samples annotated *48G* + *blocking/wood* + *crate/mil/medium* + *synthetic*: 102
# - Samples annotated *48G* + *blocking/wood* + *crate/mil/long* + *synthetic*: 99
# - Samples annotated *48G* + *blocking/wood* + *crate/mil/large* + *synthetic*: 96
# - Samples annotated *48G* + *blocking/wood* + *brick* + *synthetic*: 10
# - Samples annotated *48G* + *blocking/wood* + *brick* + *pallet* + *synthetic*: 30
# - Samples annotated *48G* + *blocking/wood* + *box/cardboard* + *synthetic*: 1
# - Samples annotated *48G* + *blocking/wood* + *box/cardboard* + *pallet* + *synthetic*: 27
# - Samples annotated *48G* + *blocking/concrete* + *synthetic*: 1548
# - Samples annotated *48G* + *blocking/concrete* + *synthetic* + *tank/water/plastic/16G*: 125
# - Samples annotated *48G* + *blocking/concrete* + *synthetic* + *tank/water/plastic/1500L*: 141
# - Samples annotated *48G* + *blocking/concrete* + *synthetic* + *tank/water/IBC/275G*: 146
# - Samples annotated *48G* + *blocking/concrete* + *synthetic* + *tank/propane/500G*: 412
# - Samples annotated *48G* + *blocking/concrete* + *synthetic* + *tank/oil/H*: 68
# - Samples annotated *48G* + *blocking/concrete* + *synthetic* + *tank/oil/G*: 58
# - Samples annotated *48G* + *blocking/concrete* + *synthetic* + *tank/oil/F*: 59
# - Samples annotated *48G* + *blocking/concrete* + *synthetic* + *tank/oil/E*: 53
# - Samples annotated *48G* + *blocking/concrete* + *synthetic* + *tank/oil/D*: 68
# - Samples annotated *48G* + *blocking/concrete* + *synthetic* + *tank/oil/C*: 45
# - Samples annotated *48G* + *blocking/concrete* + *synthetic* + *tank/oil/B*: 54
# - Samples annotated *48G* + *blocking/concrete* + *synthetic* + *tank/oil/A*: 54
# - Samples annotated *48G* + *blocking/concrete* + *synthetic* + *tank/gas/8kg*: 50
# - Samples annotated *48G* + *blocking/concrete* + *synthetic* + *tank/gas/6kg*: 73
# - Samples annotated *48G* + *blocking/concrete* + *synthetic* + *tank/gas/30kg*: 37
# - Samples annotated *48G* + *blocking/concrete* + *synthetic* + *tank/gas/20kg*: 80
# - Samples annotated *48G* + *blocking/concrete* + *synthetic* + *tank/gas/160L*: 46
# - Samples annotated *48G* + *blocking/concrete* + *synthetic* + *tank/gas/10kg*: 58
# - Samples annotated *48G* + *blocking/concrete* + *steel/roll* + *synthetic*: 1
# - Samples annotated *48G* + *blocking/concrete* + *pallet* + *synthetic*: 7
# - Samples annotated *48G* + *blocking/concrete* + *pallet* + *steel/roll* + *synthetic*: 30
# - Samples annotated *48G* + *blocking/concrete* + *paintcan/1G* + *synthetic*: 157
# - Samples annotated *48G* + *blocking/concrete* + *paintbrush* + *synthetic*: 1
# - Samples annotated *48G* + *blocking/concrete* + *paintbrush* + *paintcan/1G* + *synthetic*: 188
# - Samples annotated *48G* + *blocking/concrete* + *mdf* + *synthetic*: 32
# - Samples annotated *48G* + *blocking/concrete* + *lumber/pine* + *synthetic*: 33
# - Samples annotated *48G* + *blocking/concrete* + *keg/50L* + *synthetic*: 196
# - Samples annotated *48G* + *blocking/concrete* + *keg/30L* + *synthetic*: 211
# - Samples annotated *48G* + *blocking/concrete* + *drywall* + *synthetic*: 32
# - Samples annotated *48G* + *blocking/concrete* + *crate/mil/small* + *synthetic*: 91
# - Samples annotated *48G* + *blocking/concrete* + *crate/mil/medium* + *synthetic*: 98
# - Samples annotated *48G* + *blocking/concrete* + *crate/mil/long* + *synthetic*: 120
# - Samples annotated *48G* + *blocking/concrete* + *crate/mil/large* + *synthetic*: 100
# - Samples annotated *48G* + *blocking/concrete* + *brick* + *synthetic*: 4
# - Samples annotated *48G* + *blocking/concrete* + *brick* + *pallet* + *synthetic*: 28
# - Samples annotated *48G* + *blocking/concrete* + *box/cardboard* + *synthetic*: 2
# - Samples annotated *48G* + *blocking/concrete* + *box/cardboard* + *pallet* + *synthetic*: 34
# - Samples annotated *48G* + *block/generic* + *synthetic*: 1
# - Samples annotated *48G* + *block/generic* + *blocking/wood* + *synthetic*: 1
# - Samples annotated *48G* + *block/generic* + *blocking/concrete* + *synthetic*: 1
# - Samples annotated *48G* + *block/cinder* + *synthetic*: 1
# - Samples annotated *48G* + *block/cinder* + *pallet* + *synthetic*: 1
# - Samples annotated *48G* + *block/cinder* + *blocking/wood* + *synthetic*: 1
# - Samples annotated *48G* + *block/cinder* + *blocking/wood* + *pallet* + *synthetic*: 2
# - Samples annotated *48G* + *block/cinder* + *blocking/concrete* + *synthetic*: 1
# - Samples annotated *48G* + *block/cinder* + *blocking/concrete* + *pallet* + *synthetic*: 1
# - Samples annotated *48G* + *barrel/55G/D* + *barrel/55G/E* + *barrel/55G/F* + *blocking/concrete* + *synthetic*: 1
# - Samples annotated *48G* + *barrel/55G/C* + *blocking/wood* + *synthetic*: 1
# - Samples annotated *48G* + *barrel/55G/C* + *barrel/55G/D* + *barrel/55G/E* + *barrel/55G/F* + *synthetic*: 1
# - Samples annotated *48G* + *barrel/55G/B* + *barrel/55G/C* + *barrel/55G/F* + *blocking/concrete* + *synthetic*: 1
# - Samples annotated *48G* + *barrel/55G/A* + *barrel/55G/B* + *barrel/55G/D* + *blocking/concrete* + *synthetic*: 1
# - Samples annotated *48G* + *barrel/55G/A* + *barrel/55G/B* + *barrel/55G/C* + *barrel/55G/F* + *synthetic*: 1
# - Samples annotated *48G* + *barrel/55G* + *synthetic*: 399
# - Samples annotated *48G* + *barrel/55G* + *blocking/wood* + *synthetic*: 363
# - Samples annotated *48G* + *barrel/55G* + *blocking/concrete* + *synthetic*: 395
# - Samples annotated *48G* + *banding* + *block/generic* + *synthetic*: 10
# - Samples annotated *48G* + *banding* + *block/generic* + *pallet* + *synthetic*: 31
# - Samples annotated *48G* + *banding* + *block/generic* + *blocking/wood* + *synthetic*: 2
# - Samples annotated *48G* + *banding* + *block/generic* + *blocking/wood* + *pallet* + *synthetic*: 29
# - Samples annotated *48G* + *banding* + *block/generic* + *blocking/concrete* + *synthetic*: 3
# - Samples annotated *48G* + *banding* + *block/generic* + *blocking/concrete* + *pallet* + *synthetic*: 35
# - Samples annotated *48G* + *banding* + *block/cinder* + *synthetic*: 5
# - Samples annotated *48G* + *banding* + *block/cinder* + *pallet* + *synthetic*: 36
# - Samples annotated *48G* + *banding* + *block/cinder* + *blocking/wood* + *synthetic*: 1
# - Samples annotated *48G* + *banding* + *block/cinder* + *blocking/wood* + *pallet* + *synthetic*: 30
# - Samples annotated *48G* + *banding* + *block/cinder* + *blocking/concrete* + *synthetic*: 7
# - Samples annotated *48G* + *banding* + *block/cinder* + *blocking/concrete* + *pallet* + *synthetic*: 41
# - Samples annotated *48G* + *banding* + *barrel/55G/F* + *blocking/wood* + *synthetic*: 1
# - Samples annotated *48G* + *banding* + *barrel/55G/F* + *blocking/concrete* + *pallet* + *synthetic*: 1
# - Samples annotated *48G* + *banding* + *barrel/55G/E* + *barrel/55G/F* + *pallet* + *synthetic*: 1
# - Samples annotated *48G* + *banding* + *barrel/55G/E* + *barrel/55G/F* + *blocking/wood* + *pallet* + *synthetic*: 1
# - Samples annotated *48G* + *banding* + *barrel/55G/D* + *barrel/55G/E* + *barrel/55G/F* + *pallet* + *synthetic*: 1
# - Samples annotated *48G* + *banding* + *barrel/55G/D* + *barrel/55G/E* + *barrel/55G/F* + *blocking/wood* + *pallet* + *synthetic*: 1
# - Samples annotated *48G* + *banding* + *barrel/55G/C* + *blocking/wood* + *pallet* + *synthetic*: 1
# - Samples annotated *48G* + *banding* + *barrel/55G/C* + *blocking/concrete* + *pallet* + *synthetic*: 1
# - Samples annotated *48G* + *banding* + *barrel/55G/C* + *barrel/55G/F* + *blocking/wood* + *pallet* + *synthetic*: 2
# - Samples annotated *48G* + *banding* + *barrel/55G/C* + *barrel/55G/F* + *blocking/concrete* + *pallet* + *synthetic*: 1
# - Samples annotated *48G* + *banding* + *barrel/55G/C* + *barrel/55G/E* + *barrel/55G/F* + *pallet* + *synthetic*: 1
# - Samples annotated *48G* + *banding* + *barrel/55G/C* + *barrel/55G/E* + *barrel/55G/F* + *blocking/wood* + *pallet* + *synthetic*: 1
# - Samples annotated *48G* + *banding* + *barrel/55G/C* + *barrel/55G/E* + *barrel/55G/F* + *blocking/concrete* + *pallet* + *synthetic*: 1
# - Samples annotated *48G* + *banding* + *barrel/55G/C* + *barrel/55G/D* + *barrel/55G/E* + *barrel/55G/F* + *blocking/concrete* + *pallet* + *synthetic*: 1
# - Samples annotated *48G* + *banding* + *barrel/55G/B* + *barrel/55G/D* + *barrel/55G/E* + *blocking/wood* + *pallet* + *synthetic*: 1
# - Samples annotated *48G* + *banding* + *barrel/55G/B* + *barrel/55G/C* + *blocking/wood* + *pallet* + *synthetic*: 1
# - Samples annotated *48G* + *banding* + *barrel/55G/B* + *barrel/55G/C* + *barrel/55G/F* + *pallet* + *synthetic*: 1
# - Samples annotated *48G* + *banding* + *barrel/55G/B* + *barrel/55G/C* + *barrel/55G/F* + *blocking/concrete* + *pallet* + *synthetic*: 1
# - Samples annotated *48G* + *banding* + *barrel/55G/B* + *barrel/55G/C* + *barrel/55G/E* + *barrel/55G/F* + *pallet* + *synthetic*: 1
# - Samples annotated *48G* + *banding* + *barrel/55G/B* + *barrel/55G/C* + *barrel/55G/D* + *barrel/55G/E* + *barrel/55G/F* + *synthetic*: 1
# - Samples annotated *48G* + *banding* + *barrel/55G/B* + *barrel/55G/C* + *barrel/55G/D* + *barrel/55G/E* + *barrel/55G/F* + *pallet* + *synthetic*: 2
# - Samples annotated *48G* + *banding* + *barrel/55G/A* + *barrel/55G/D* + *pallet* + *synthetic*: 1
# - Samples annotated *48G* + *banding* + *barrel/55G/A* + *barrel/55G/D* + *barrel/55G/E* + *barrel/55G/F* + *pallet* + *synthetic*: 1
# - Samples annotated *48G* + *banding* + *barrel/55G/A* + *barrel/55G/D* + *barrel/55G/E* + *barrel/55G/F* + *blocking/wood* + *pallet* + *synthetic*: 1
# - Samples annotated *48G* + *banding* + *barrel/55G/A* + *barrel/55G/B* + *blocking/concrete* + *pallet* + *synthetic*: 1
# - Samples annotated *48G* + *banding* + *barrel/55G/A* + *barrel/55G/B* + *barrel/55G/D* + *barrel/55G/E* + *blocking/wood* + *pallet* + *synthetic*: 2
# - Samples annotated *48G* + *banding* + *barrel/55G/A* + *barrel/55G/B* + *barrel/55G/D* + *barrel/55G/E* + *blocking/concrete* + *pallet* + *synthetic*: 1
# - Samples annotated *48G* + *banding* + *barrel/55G/A* + *barrel/55G/B* + *barrel/55G/D* + *barrel/55G/E* + *barrel/55G/F* + *blocking/wood* + *pallet* + *synthetic*: 1
# - Samples annotated *48G* + *banding* + *barrel/55G/A* + *barrel/55G/B* + *barrel/55G/C* + *pallet* + *synthetic*: 1
# - Samples annotated *48G* + *banding* + *barrel/55G/A* + *barrel/55G/B* + *barrel/55G/C* + *barrel/55G/F* + *pallet* + *synthetic*: 1
# - Samples annotated *48G* + *banding* + *barrel/55G/A* + *barrel/55G/B* + *barrel/55G/C* + *barrel/55G/F* + *blocking/wood* + *pallet* + *synthetic*: 1
# - Samples annotated *48G* + *banding* + *barrel/55G/A* + *barrel/55G/B* + *barrel/55G/C* + *barrel/55G/E* + *barrel/55G/F* + *pallet* + *synthetic*: 1
# - Samples annotated *48G* + *banding* + *barrel/55G/A* + *barrel/55G/B* + *barrel/55G/C* + *barrel/55G/E* + *barrel/55G/F* + *blocking/wood* + *pallet* + *synthetic*: 1
# - Samples annotated *48G* + *banding* + *barrel/55G/A* + *barrel/55G/B* + *barrel/55G/C* + *barrel/55G/E* + *barrel/55G/F* + *blocking/concrete* + *pallet* + *synthetic*: 1
# - Samples annotated *48G* + *banding* + *barrel/55G/A* + *barrel/55G/B* + *barrel/55G/C* + *barrel/55G/D* + *blocking/wood* + *pallet* + *synthetic*: 2
# - Samples annotated *48G* + *banding* + *barrel/55G/A* + *barrel/55G/B* + *barrel/55G/C* + *barrel/55G/D* + *barrel/55G/E* + *blocking/concrete* + *pallet* + *synthetic*: 1
# - Samples annotated *48G* + *banding* + *barrel/55G/A* + *barrel/55G/B* + *barrel/55G/C* + *barrel/55G/D* + *barrel/55G/E* + *barrel/55G/F* + *synthetic*: 1
# - Samples annotated *48G* + *banding* + *barrel/55G/A* + *barrel/55G/B* + *barrel/55G/C* + *barrel/55G/D* + *barrel/55G/E* + *barrel/55G/F* + *pallet* + *synthetic*: 19
# - Samples annotated *48G* + *banding* + *barrel/55G/A* + *barrel/55G/B* + *barrel/55G/C* + *barrel/55G/D* + *barrel/55G/E* + *barrel/55G/F* + *blocking/wood* + *pallet* + *synthetic*: 19
# - Samples annotated *48G* + *banding* + *barrel/55G/A* + *barrel/55G/B* + *barrel/55G/C* + *barrel/55G/D* + *barrel/55G/E* + *barrel/55G/F* + *blocking/concrete* + *synthetic*: 1
# - Samples annotated *48G* + *banding* + *barrel/55G/A* + *barrel/55G/B* + *barrel/55G/C* + *barrel/55G/D* + *barrel/55G/E* + *barrel/55G/F* + *blocking/concrete* + *pallet* + *synthetic*: 18
# - Samples annotated *48G* + *bag/sand* + *synthetic*: 8
# - Samples annotated *48G* + *bag/sand* + *pallet* + *synthetic*: 33
# - Samples annotated *48G* + *bag/sand* + *blocking/wood* + *synthetic*: 1
# - Samples annotated *48G* + *bag/sand* + *blocking/wood* + *pallet* + *synthetic*: 34
# - Samples annotated *48G* + *bag/sand* + *blocking/concrete* + *synthetic*: 2
# - Samples annotated *48G* + *bag/sand* + *blocking/concrete* + *pallet* + *synthetic*: 29
# - Samples annotated *48G* + *bag/salt* + *synthetic*: 10
# - Samples annotated *48G* + *bag/salt* + *pallet* + *synthetic*: 36
# - Samples annotated *48G* + *bag/salt* + *blocking/wood* + *synthetic*: 4
# - Samples annotated *48G* + *bag/salt* + *blocking/wood* + *pallet* + *synthetic*: 37
# - Samples annotated *48G* + *bag/salt* + *blocking/concrete* + *synthetic*: 10
# - Samples annotated *48G* + *bag/salt* + *blocking/concrete* + *pallet* + *synthetic*: 32
# - Samples annotated *48G* + *bag/cement* + *synthetic*: 7
# - Samples annotated *48G* + *bag/cement* + *pallet* + *synthetic*: 30
# - Samples annotated *48G* + *bag/cement* + *blocking/wood* + *synthetic*: 10
# - Samples annotated *48G* + *bag/cement* + *blocking/wood* + *pallet* + *synthetic*: 43
# - Samples annotated *48G* + *bag/cement* + *blocking/concrete* + *synthetic*: 6
# - Samples annotated *48G* + *bag/cement* + *blocking/concrete* + *pallet* + *synthetic*: 31
#
# **Category Definitions**
#
# - bag/cement: bags of cement neatly stacked on a forklift pallet.
# - bag/salt: bags of salt neatly stacked on a forklift pallet.
# - bag/sand: bags of sand neatly stacked on a forklift pallet.
# - banding: banding used to keep pallet loads of blocks intact.
# - barrel/55G: standalone 55 gallon barrels.
# - barrel/55G/A - barrel/55G/F: each of six 55 gallon barrels stacked on a pallet.
# - block/cinder: cinderblock neatly stacked on a forklift pallet.
# - block/generic: large masonry blocks neatly stacked on a forklift pallet.
# - box/cardboard: cardboard boxes neatly stacked on a forklift pallet.
# - brick: standard bricks, neatly stacked on a forklift pallet and covered in translucent plastic.
# - crate/mil/large, crate/mil/long, crate/mil/medium, crate/mil/small: four different sizes of plastic military crate.
# - drywall: neat stack of sheets of drywall, covered in translucent plastic.
# - keg/30L, keg/50L: two sizes of beer keg.
# - lumber/pine: neat stack of pine lumber.
# - mdf: neat stack of sheets of MDF
# - paintbrush: standard bristle paintbrush.
# - paintcan/1G: one gallon paint can.
# - pallet: wood forklift pallet.
# - steel/roll: large roll of sheetmetal.
# - synthetic: samples generated using our synthetic workflow.
# - tank/gas/6kg - tank/gas/160L: various sizes of gas cylinder.
# - tank/oil/A - tank/oil/H: various types of large industrial oil storage.
# - tank/propane/500G: commonly seen household propane storage tank.
# - tank/water/IBC/275G, tank/water/plastic/1500L, tank/water/plastic/16G: various sizes of water storage.
#
# **Questions**
#
# <dl>
#   <dt>Why are there only 49991 samples with bounding boxes?</dt>
#   <dd>In theory, every sample should contain at least one bounding box.  However, our randomly chosen camera angles occasionally put the distractors and cylinders completely off screen.  This leads to a sample tagged *synthetic* that doesn't contain any bounding boxes.</dd>
# </dl>
